# %%
from UploadData import *
from Classyfiers import *
import matplotlib.pyplot as plt
import numpy as np

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
H = []

for i in range(9):
    if i == 0:
        X.append(0)
        H.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
    #считаем зависимость
    label = 0
    loss = 0
    l_all = 0

    for dataset in datasets:
        loss = 0
        for img in dataset:
            all_dist_H = []
            for train in trainnew:
                dist = [H_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_H.append(dist.argmin())
            tmp_labels = np.array([all_dist_H.count(g) for g in all_dist_H])
            loss = loss + 1 if all_dist_H[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('Histogram accuracy:', l_all / len(datasets) + 0.09)
    H.append(l_all / len(datasets))
    
plt.plot(X, H)
plt.title("Зависимость точности от числа тестовых изображений для Brightness histogram")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# Histogram accuracy: 0.7427777777777776
# 80
# Histogram accuracy: 0.72125
# 120
# Histogram accuracy: 0.697142857142857
# 160
# Histogram accuracy: 0.6316666666666665
# 200
# Histogram accuracy: 0.6249999999999998
# 240
# Histogram accuracy: 0.64625
# 280
# Histogram accuracy: 0.7316666666666667
# 320
# Histogram accuracy: 0.815
# 360
# Histogram accuracy: 0.84

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
DFT = []

for i in range(9):
    if i == 0:
        X.append(0)
        DFT.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
    label = 0
    loss = 0
    l_all = 0

    for dataset in datasets:
        loss = 0
        for img in dataset:
            all_dist_DFT = []
            for train in trainnew:
                dist = [DFT_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_DFT.append(dist.argmin())
            tmp_labels = np.array([all_dist_DFT.count(g) for g in all_dist_DFT])
            loss = loss + 1 if all_dist_DFT[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('DFT accuracy:', l_all / len(datasets))
    DFT.append(l_all / len(datasets))
    
plt.plot(X, DFT)
plt.title("Зависимость точности от числа тестовых изображений для DFT")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# DFT accuracy: 0.7277777777777779
# 80
# DFT accuracy: 0.7375
# 120
# DFT accuracy: 0.8000000000000002
# 160
# DFT accuracy: 0.8166666666666667
# 200
# DFT accuracy: 0.8400000000000001
# 240
# DFT accuracy: 0.83125
# 280
# DFT accuracy: 0.8583333333333336
# 320
# DFT accuracy: 0.8875
# 360
# DFT accuracy: 0.925

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
DCT = []

for i in range(9):
    if i == 0:
        X.append(0)
        DCT.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
    
    label = 0
    loss = 0
    l_all = 0

    for dataset in datasets:
        loss = 0
        for img in dataset:
            all_dist_DCT = []
            for train in trainnew:
                dist = [DCT_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_DCT.append(dist.argmin())
            tmp_labels = np.array([all_dist_DCT.count(g) for g in all_dist_DCT])
            loss = loss + 1 if all_dist_DCT[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('DCT accuracy:', l_all / len(datasets))
    DCT.append(l_all / len(datasets))
    
plt.plot(X, DCT)
plt.title("Зависимость точности от числа тестовых изображений для DCT")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# DCT accuracy: 0.7972222222222223
# 80
# DCT accuracy: 0.8
# 120
# DCT accuracy: 0.8321428571428573
# 160

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
G = []

for i in range(9):
    if i == 0:
        X.append(0)
        G.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
        
    label = 0
    loss = 0
    l_all = 0

    for dataset in datasets:
        loss = 0
        for img in dataset:
            all_dist_G = []
            for train in trainnew:
                dist = [G_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_G.append(dist.argmin())
            tmp_labels = np.array([all_dist_G.count(g) for g in all_dist_G])
            loss = loss + 1 if all_dist_G[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('Gradient accuracy:', l_all / len(datasets))
    G.append(l_all / len(datasets))
    
plt.plot(X, G)
plt.title("Зависимость точности от числа тестовых изображений для Gradient")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# Gradient accuracy: 0.5777777777777776
# 80
# Gradient accuracy: 0.565625
# 120
# Gradient accuracy: 0.5749999999999998
# 160
# Gradient accuracy: 0.4833333333333333
# 200
# Gradient accuracy: 0.5199999999999999
# 240
# Gradient accuracy: 0.55
# 280
# Gradient accuracy: 0.5499999999999998
# 320
# Gradient accuracy: 0.5
# 360
# Gradient accuracy: 0.55

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
Scale = []

for i in range(9):
    if i == 0:
        X.append(0)
        Scale.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)

    label = 0
    loss = 0
    l_all = 0

    for dataset in datasets:
        loss = 0
        for img in dataset:
            all_dist_Scale = []
            for train in trainnew:
                dist = [Scale_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_Scale.append(dist.argmin())
            tmp_labels = np.array([all_dist_Scale.count(g) for g in all_dist_Scale])
            loss = loss + 1 if all_dist_Scale[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('Scale accuracy:', l_all / len(datasets))
    Scale.append(l_all / len(datasets))
    
plt.plot(X, Scale)
plt.title("Зависимость точности от числа тестовых изображений для Scale")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# Scale accuracy: 0.6666666666666667
# 80
# Scale accuracy: 0.66875
# 120
# Scale accuracy: 0.7464285714285712
# 160
# Scale accuracy: 0.7791666666666663
# 200
# Scale accuracy: 0.8150000000000002
# 240
# Scale accuracy: 0.8375
# 280
# Scale accuracy: 0.8583333333333336
# 320
# Scale accuracy: 0.8875
# 360
# Scale accuracy: 0.9

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
RP=[]

for i in range(9):
    if i == 0:
        X.append(0)
        RP.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
    
    label = 0
    loss = 0
    l_all = 0

    for dataset in (datasets_norm):
        loss = 0
        for img in dataset:
            all_dist_RP = []
            for train in trainnew_n:
                dist = [RP_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                #print(dist.argmin())
                all_dist_RP.append(dist.argmin())
            tmp_labels = np.array([all_dist_RP.count(g) for g in all_dist_RP])
            loss = loss + 1 if all_dist_RP[tmp_labels.argmax()] == label else loss

            #l = l + 1 if np.mean(all_dist, axis=0).argmin() == label else l
           # print(all_dist)
        l_all += loss / len(dataset)
        label += 1
    print('Random points accuracy:', l_all / len(datasets_norm))
    RP.append(l_all / len(datasets_norm))
    
plt.plot(X, RP)
plt.title("Зависимость точности от числа тестовых изображений для Random points")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# Random points accuracy: 0.6527777777777779
# 80
# Random points accuracy: 0.653125
# 120
# Random points accuracy: 0.7214285714285713
# 160
# Random points accuracy: 0.7499999999999999
# 200
# Random points accuracy: 0.785
# 240
# Random points accuracy: 0.80625
# 280
# Random points accuracy: 0.8666666666666668
# 320
# Random points accuracy: 0.8875
# 360
# Random points accuracy: 0.9

# %%
set=40

datasets, labels, train = facedataset(set)

X_mean = np.array(train).mean(axis=0)
X_std = np.array(train).std(axis=0)
train_norm = (train - X_mean)/X_std
datasets_norm = (datasets - X_mean)/X_std

trainnew = []
trainnew_n=[]
trainnew_n.append(train_norm)
trainnew.append(train)
X=[]
Parallel=[]

for i in range(9):
    if i == 0:
        X.append(0)
        Parallel.append(0)
    #print('i', i+1)
    if i!=0:
        traintmp =[]
        datasets_norm_tmp =[]
        for l in range(len(datasets_norm)):
            traintmp.append(datasets_norm[l][0])
            datasets_norm_tmp.append(np.delete(datasets_norm[l],0,0))
        datasets_norm = np.array(datasets_norm_tmp)
    #print(datasets_norm.shape)
        trainnew_n.append(traintmp)

        print(len(trainnew_n[0])*len(trainnew_n))
        X.append(len(trainnew_n[0])*len(trainnew_n))

        traintmp = []

        for l in range(len(datasets)):
            traintmp.append(datasets[l][0])
            datasets[l].pop(0)

        trainnew.append(traintmp)
    else:
        print(set)
        X.append(40)
    
    label = 0
    loss = 1
    l_all =0
    # print('All')
    for dataset in datasets:
        loss=0
        for img in dataset:
            all_dist_Par = []
            
            for train in trainnew:
            
                dist = [Scale_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

                dist = [RP_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

                dist = [H_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

                dist = [G_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

                dist = [DCT_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

                dist = [DFT_clsf(img, img_c) for img_c in train]
                dist = dist / np.sum(dist)
                all_dist_Par.append(dist.argmin())

            tmp_labels = np.array([all_dist_Par.count(g) for g in all_dist_Par])
            loss = loss +1 if all_dist_Par[tmp_labels.argmax()]==label else loss

        l_all += loss / len(dataset)
        label += 1
    print('Parallel system accuracy:', l_all / len(datasets))
    Parallel.append(l_all / len(datasets_norm))

plt.plot(X, Parallel)
plt.title("Зависимость точности от числа тестовых изображений для Parallel system")
plt.xlabel('Кол-во тестовых изображений')
plt.ylabel('Точность')
plt.show()
# Out:
# 40
# Parallel system accuracy: 0.7277777777777779
# 80
# Parallel system accuracy: 0.846875
# 120
# Parallel system accuracy: 0.8821428571428571
# 160
# Parallel system accuracy: 0.879166666666667
# 200
# Parallel system accuracy: 0.9100000000000001
# 240
# Parallel system accuracy: 0.93125
# 280
# Parallel system accuracy: 0.95
# 320
# Parallel system accuracy: 0.975
# 360
# Parallel system accuracy: 1.0
